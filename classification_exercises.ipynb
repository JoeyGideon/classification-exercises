# %% [markdown]
#  Create a pandas dataframe, df_iris, from this data.
#
# print the first 3 rows
# print the number of rows and columns (shape)
# print the column names
# print the data type of each column
# print the summary statistics for each of the numeric variables

# %%
import pandas as pd
import seaborn as sns

# load the iris dataset
iris = sns.load_dataset('iris')

# %%
# assign the dataset to a DataFrame
df_iris = pd.DataFrame(iris)

# %%
# print the first 3 rows
print(df_iris.head(3))
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
# print the number of rows and columns (shape)
print(df_iris.shape)
# Out:
# (150, 5)

# %%
# print the column names
print(df_iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# print the data type of each column
print(df_iris.dtypes)
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# print the summary statistics for each of the numeric variables
print(df_iris.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Read the data from this google sheet (https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357) into a dataframe, df_google.
#
# print the first 3 rows
# print the number of rows and columns
# print the column names
# print the data type of each column
# print the summary statistics for each of the numeric variables
# print the unique values for each of your categorical variables

# %%
import pandas as pd

sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_googlesheet = pd.read_csv(csv_export_url)
df_googlesheet.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd

sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_google = pd.read_csv(csv_export_url)

# print the first 3 rows
print(df_google.head(3))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# print the number of rows and columns
print(df_google.shape)
# Out:
# (891, 12)

# %%
# print the column names
print(df_google.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# print the data type of each column
print(df_google.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# print the summary statistics for each of the numeric variables
print(df_google.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# unique catagories are the columns
print(df_google.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Download the previous exercise's file into an excel (File → Download → Microsoft Excel). Read the downloaded file into a dataframe named df_excel.
#
# assign the first 100 rows to a new dataframe, df_excel_sample
# print the number of rows of your original dataframe
# print the first 5 column names
# print the column names that have a data type of object
# compute the range for each of the numeric variables.

# %%
# File paths can be local.csv files or hosted .csv files
url = "/Users/jogideon/codeup-data-science/classification-exercises/train - train.csv"

df_excel = pd.read_csv(url)
df_excel.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Data Preperation

# %%
# Using the Iris Data: 
# Use the function defined in acquire.py to load the iris data.

from acquire import get_iris_data

# Load iris data into a pandas DataFrame
df_iris = get_iris_data()

# Display the first 5 rows of the DataFrame
df_iris.head()
# Out:
#    species_id species_name  sepal_length  sepal_width  petal_length  \
# 0           1       setosa           5.1          3.5           1.4
# 1           1       setosa           4.9          3.0           1.4
# 2           1       setosa           4.7          3.2           1.3
# 3           1       setosa           4.6          3.1           1.5
# 4           1       setosa           5.0          3.6           1.4
#
#    petal_width
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2

# %%
# Drop the species_id and measurement_id columns. (There is no measurement_id column)

# Drop the species_id and measurement_id columns from the DataFrame
df_iris = df_iris.drop(columns=['species_id'])

# Display the first 5 rows of the updated DataFrame
df_iris.head()
# Out:
#   species_name  sepal_length  sepal_width  petal_length  petal_width
# 0       setosa           5.1          3.5           1.4          0.2
# 1       setosa           4.9          3.0           1.4          0.2
# 2       setosa           4.7          3.2           1.3          0.2
# 3       setosa           4.6          3.1           1.5          0.2
# 4       setosa           5.0          3.6           1.4          0.2

# %%
# Rename the species_name column to just species.

# Rename the species_name column to species
df_iris = df_iris.rename(columns={'species_name': 'species'})

# Display the first 5 rows of the updated DataFrame
df_iris.head()
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width
# 0  setosa           5.1          3.5           1.4          0.2
# 1  setosa           4.9          3.0           1.4          0.2
# 2  setosa           4.7          3.2           1.3          0.2
# 3  setosa           4.6          3.1           1.5          0.2
# 4  setosa           5.0          3.6           1.4          0.2

# %%
# Create dummy variables of the species name and concatenate onto the iris dataframe. 
# (This is for practice, we don't always have to encode the target, but if we used species as a feature, we would need to encode it).

# Create dummy variables of the species column
species_dummies = pd.get_dummies(df_iris['species'], drop_first=True)

# Concatenate the dummy variables onto the original DataFrame
df_iris = pd.concat([df_iris, species_dummies], axis=1)

# Display the first 5 rows of the updated DataFrame
df_iris.head()
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width  versicolor  \
# 0  setosa           5.1          3.5           1.4          0.2           0
# 1  setosa           4.9          3.0           1.4          0.2           0
# 2  setosa           4.7          3.2           1.3          0.2           0
# 3  setosa           4.6          3.1           1.5          0.2           0
# 4  setosa           5.0          3.6           1.4          0.2           0
#
#    virginica
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

import pandas as pd

def prep_iris(df):
    '''
    This function accepts the untransformed iris data as a pandas DataFrame and applies the following transformations:
    - Drops the species_id column
    - Renames the species_name column to species
    - Creates dummy variables of the species column and concatenates them onto the original DataFrame
    '''
    # Drop the species_id column from the DataFrame
    df = df.drop(columns=['species_id'])

    # Rename the species_name column to species
    df = df.rename(columns={'species_name': 'species'})

    # Create dummy variables of the species column
    species_dummies = pd.get_dummies(df['species'], drop_first=True)

    # Concatenate the dummy variables onto the original DataFrame
    df = pd.concat([df, species_dummies], axis=1)

    return df

# %% [markdown]
# Using the Titanic dataset
#
# Use the function defined in acquire.py to load the Titanic data.

# %%
import pandas as pd
from acquire import get_titanic_data

# Load Titanic data into a pandas DataFrame
df_titanic = get_titanic_data()

# Display the first 5 rows of the DataFrame
df_titanic.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class deck  embark_town  alone
# 0        S  Third  NaN  Southampton      0
# 1        C  First    C    Cherbourg      0
# 2        S  Third  NaN  Southampton      1
# 3        S  First    C  Southampton      0
# 4        S  Third  NaN  Southampton      1

# %%
# Drop unnecessary columns from the DataFrame
df_titanic = df_titanic.drop(columns=['embarked', 'pclass', 'sibsp', 'parch'])

# Display the first 5 rows of the updated DataFrame
df_titanic.head()
# Out:
#    passenger_id  survived     sex   age     fare  class deck  embark_town  \
# 0             0         0    male  22.0   7.2500  Third  NaN  Southampton
# 1             1         1  female  38.0  71.2833  First    C    Cherbourg
# 2             2         1  female  26.0   7.9250  Third  NaN  Southampton
# 3             3         1  female  35.0  53.1000  First    C  Southampton
# 4             4         0    male  35.0   8.0500  Third  NaN  Southampton
#
#    alone
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %%
# Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# Encode categorical columns
df_titanic['sex'] = pd.get_dummies(df_titanic['sex'], drop_first=True)
df_titanic = pd.concat([df_titanic,pd.get_dummies(df_titanic['embark_town'], prefix='embark', drop_first=True)], axis=1)

# Drop original categorical columns that have been encoded
df_titanic = df_titanic.drop(columns=['sex', 'embark_town'])

# Display the first 5 rows of the updated DataFrame
df_titanic.head()
# Out:
#    passenger_id  survived   age     fare  class deck  alone  \
# 0             0         0  22.0   7.2500  Third  NaN      0
# 1             1         1  38.0  71.2833  First    C      0
# 2             2         1  26.0   7.9250  Third  NaN      1
# 3             3         1  35.0  53.1000  First    C      0
# 4             4         0  35.0   8.0500  Third  NaN      1
#
#    embark_Queenstown  embark_Southampton
# 0                  0                   1
# 1                  0                   0
# 2                  0                   1
# 3                  0                   1
# 4                  0                   1

# %%
# Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

def prep_titanic(df):

    # Drop unnecessary columns
    df = df.drop(columns=['deck', 'embark_town', 'survived', 'class'])
    
    # Fill missing values
    df['age'] = df['age'].fillna(df['age'].median())
    df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])
    
    # Encode categorical columns
    df['sex'] = pd.get_dummies(df['sex'], drop_first=True)
    df = pd.concat([df,pd.get_dummies(df['embarked'], prefix='embarked', drop_first=True)], axis=1)
    
    # Drop original categorical columns that have been encoded
    df = df.drop(columns=['embarked'])
    
    # Return the updated DataFrame
    return df

# %% [markdown]
# Using the Telco dataset
#
# Use the function defined in acquire.py to load the Telco data.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from acquire import get_telco_data

# Load Telco data into a pandas DataFrame
df_telco = get_telco_data()

# %%
# Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.

df_telco = df_telco.drop(['payment_type_id', 'internet_service_type_id', 'contract_type_id', 'customer_id'], axis=1)
df_telco.head()
# Out:
#    gender  senior_citizen partner dependents  tenure phone_service  \
# 0  Female               0     Yes        Yes       9           Yes
# 1    Male               0      No         No       9           Yes
# 2    Male               0      No         No       4           Yes
# 3    Male               1     Yes         No      13           Yes
# 4  Female               1     Yes         No       3           Yes
#
#   multiple_lines online_security online_backup device_protection tech_support  \
# 0             No              No           Yes                No          Yes
# 1            Yes              No            No                No           No
# 2             No              No            No               Yes           No
# 3             No              No           Yes               Yes           No
# 4             No              No            No                No          Yes
#
#   streaming_tv streaming_movies paperless_billing  monthly_charges  \
# ...

# %%
# Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

import pandas as pd

# Load Telco data into a pandas DataFrame
df_telco = get_telco_data()

# Drop any unnecessary, unhelpful, or duplicated columns
df_telco = df_telco.drop(['payment_type_id', 'internet_service_type_id', 'contract_type_id', 'customer_id'], axis=1)

# Encode the 'churn' column as 1 for 'Yes' and 0 for 'No'
df_telco['churn'] = df_telco['churn'].replace({'Yes': 1, 'No': 0})

# Get the categorical columns
cat_cols = ['gender', 'partner', 'dependents', 'phone_service', 'multiple_lines',
            'online_security', 'online_backup', 'device_protection', 'tech_support',
            'streaming_tv', 'streaming_movies', 'paperless_billing',
            'contract_type', 'internet_service_type', 'payment_type']

# Use get_dummies() to create dummy variables
dummy_df = pd.get_dummies(df_telco[cat_cols], drop_first=True)

# Concatenate the dummy variables onto the original DataFrame
df_telco = pd.concat([df_telco, dummy_df], axis=1)

# Drop the original categorical columns
df_telco.drop(cat_cols, axis=1, inplace=True)

# Set the 'churn' column as the target variable
target = 'churn'

# %%
#Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.

# Prepare function
def prep_telco(df):
    # Drop duplicate rows
    df = df.drop_duplicates()

    # Replace blank values with NaN
    df = df.replace("", pd.np.nan)

    # Replace "No internet service" with "No" for relevant columns
    cols = ['online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies']
    for col in cols:
        df[col] = df[col].replace("No internet service", "No")

    # Replace binary columns with 1 (Yes) and 0 (No)
    binary_cols = ['partner', 'dependents', 'phone_service', 'multiple_lines', 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies', 'paperless_billing', 'churn']
    for col in binary_cols:
        df[col] = df[col].replace({"Yes": 1, "No": 0})

    # Convert total_charges to a numeric data type
    df['total_charges'] = pd.to_numeric(df['total_charges'], errors='coerce')
    
    # Encode the categorical columns
    cat_cols = ['gender', 'partner', 'dependents', 'phone_service', 'multiple_lines',
            'online_security', 'online_backup', 'device_protection', 'tech_support',
            'streaming_tv', 'streaming_movies', 'paperless_billing',
            'contract_type', 'internet_service_type', 'payment_type']

    dummy_df = pd.get_dummies(df[cat_cols], drop_first=True)

    df = pd.concat([df, dummy_df], axis=1)

    df.drop(cat_cols, axis=1, inplace=True)

    return df

# %%
# Split your data
# Write a function to split your data into train, test and validate datasets. Add this function to prepare.py.

def split_data(df, target):
    '''
    take in a DataFrame and return train, validate, and test DataFrames; stratify on target variable.
    return train, validate, test DataFrames.
    '''
    train_validate, test = train_test_split(df, test_size=.2, random_state=123, stratify=df[target])
    train, validate = train_test_split(train_validate, 
                                       test_size=.3, 
                                       random_state=123, 
                                       stratify=train_validate[target])
    return train, validate, test

# %%
# Run the function on the Iris dataset, returning 3 datasets, train_iris, validate_iris and test_iris.
import pandas as pd
from acquire import get_iris_data
from sklearn.model_selection import train_test_split

# Define the target variable
target = 'species'

# Split the data into train, validate, and test datasets
train_iris, validate_iris, test_iris = split_data(df_iris, target)
print(f'Train: {train_iris.shape}, Validate: {validate_iris.shape}, Test: {test_iris.shape}')
# Out:
# Train: (84, 5), Validate: (36, 5), Test: (30, 5)

# %%
# Run the function on the Titanic dataset, returning 3 datasets, train_titanic, validate_titanic and test_titanic.

import pandas as pd
from acquire import get_titanic_data
from sklearn.model_selection import train_test_split

target = 'survived'
train_titanic, validate_titanic, test_titanic = split_data(df_titanic, target)

# Print the three datasets

print(f'Train: {train_titanic.shape}, Validate: {validate_titanic.shape}, Test: {test_titanic.shape}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/lt/y6xmh16d01v7kft3lkkslw4h0000gn/T/ipykernel_43466/3789253048.py in <module>
#       6
#       7 target = 'survived'
# ----> 8 train_titanic, validate_titanic, test_titanic = split_data(df_titanic, target)
#       9
#      10 # Print the three datasets
#
# NameError: name 'df_titanic' is not defined

# %%
# Run the function on the Telco_churn dataset, returning 3 datasets, train_telco, validate_telco and test_telco.

# Split the data into train, validate, and test sets
target = 'churn'
train_telco, validate_telco, test_telco = split_data(df_telco, target)
# Print the shapes of the resulting dataframes
print(f'Train: {train_telco.shape}, Validate: {validate_telco.shape}, Test: {test_telco.shape}')
# Out:
# Train: (3943, 31), Validate: (1691, 31), Test: (1409, 31)

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.model_selection import train_test_split

np.random.seed(123)

# %%
# assign the dataset to a DataFrame
df_iris = pd.DataFrame(iris)

# %%
def prep_iris(df):
    '''
    This function accepts the untransformed iris data as a pandas DataFrame and applies the following transformations:
    - Drops the species_id column
    - Renames the species_name column to species
    - Creates dummy variables of the species column and concatenates them onto the original DataFrame
    '''
    # Drop the species_id column from the DataFrame
    df = df.drop(columns=['species_id'])

    # Rename the species_name column to species
    df = df.rename(columns={'species_name': 'species'})

    # Create dummy variables of the species column
    species_dummies = pd.get_dummies(df['species'], drop_first=True)

    # Concatenate the dummy variables onto the original DataFrame
    df = pd.concat([df, species_dummies], axis=1)

    return df

# %%
def split_data(df, target):
    '''
    take in a DataFrame and return train, validate, and test DataFrames; stratify on target variable.
    return train, validate, test DataFrames.
    '''
    train_validate, test = train_test_split(df, test_size=.2, random_state=123, stratify=df[target])
    train, validate = train_test_split(train_validate, 
                                       test_size=.3, 
                                       random_state=123, 
                                       stratify=train_validate[target])
    return train, validate, test

# %%
# Stratify with categorical target variables
train, validate, test = split_data(df_iris, target='species')
train.shape, validate.shape, test.shape
# Out:
# ((84, 5), (36, 5), (30, 5))

# %%
train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 79            5.7          2.6           3.5          1.0  versicolor
# 36            5.5          3.5           1.3          0.2      setosa
# 133           6.3          2.8           5.1          1.5   virginica
# 95            5.7          3.0           4.2          1.2  versicolor
# 18            5.7          3.8           1.7          0.3      setosa

# %%
# iris_db: Using iris data from our mySQL server and the methods used in the lesson above:

# Acquire, prepare & split your data.

# Univariate Stats

# create a histogram for each quantitative variable
train.hist()

# create a boxplot for each quantitative variable
sns.boxplot(data=train)

# compute descriptive statistics for each quantitative variable
print(train.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     84.000000    84.000000     84.000000    84.000000
# mean       5.870238     3.075000      3.771429     1.203571
# std        0.769099     0.448256      1.734940     0.752577
# min        4.400000     2.200000      1.200000     0.100000
# 25%        5.375000     2.800000      1.600000     0.400000
# 50%        5.800000     3.000000      4.250000     1.300000
# 75%        6.400000     3.400000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# For each species (categorical variable): create a frequency table and a bar plot of those frequencies.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# create a frequency table for each species
freq_table = pd.crosstab(index=train['species'], columns='count')
print(freq_table)

# create a bar plot for each species
sns.countplot(x='species', data=train)
plt.show()
# Out:
# col_0       count
# species
# setosa         28
# versicolor     28
# virginica      28

# %% [markdown]
# # Document takeaways & any actions
#
# Some takeaways from this analysis could be:
# - The petal length and petal width variables are more useful in distinguishing between
#  the different iris species than the sepal length and sepal width variables.
# - The setosa species has the smallest petals and sepals, while the virginica species has the largest petals and sepals.
# - We can use this information to build a classification model to predict the species of an iris flower based on its measurements.
#
# As for actions, we could further explore and analyze the correlations between the variables to gain more insights about the dataset.
# We could also use machine learning algorithms to build a classification model and evaluate its accuracy in predicting the species
# of an iris flower.

# %%
# Visualize each measurement type (y-axis) with the species variable (x-axis) using barplots, adding a horizontal line showing the overall mean of the metric (y-axis).
# create barplots for each measurement type with the species variable
fig, axs = plt.subplots(ncols=4, figsize=(15, 5))
for idx, var in enumerate(list(iris.columns)[:-1]):
    sns.barplot(x='species', y=var, data=train, ax=axs[idx])
    axs[idx].axhline(train[var].mean(), color='red', linestyle='dashed')
plt.show()

# %%
# For each measurement type, compute the descriptive statistics for each species.
# compute descriptive statistics for each species for each measurement type
species_list = train.species.unique()
for var in list(train.columns)[:-1]:
    print("Descriptive statistics for", var)
    for species in species_list:
        subset = train[train.species == species]
        print("Species:", species)
        print(subset[var].describe())
    print("============================================")
# Out:
# Descriptive statistics for sepal_length
# Species: versicolor
# count    28.000000
# mean      5.896429
# std       0.425556
# min       4.900000
# 25%       5.600000
# 50%       5.800000
# 75%       6.125000
# max       6.900000
# Name: sepal_length, dtype: float64
# Species: setosa
# count    28.000000
# mean      5.089286
# std       0.360390
# min       4.400000
# 25%       4.875000
# 50%       5.000000
# 75%       5.400000
# max       5.800000
# Name: sepal_length, dtype: float64
# Species: virginica
# count    28.000000
# mean      6.625000
# std       0.532378
# min       5.800000
# 25%       6.300000
# 50%       6.450000
# 75%       6.900000
# max       7.900000
# Name: sepal_length, dtype: float64
# ...
# Descriptive statistics for sepal_width
# Species: versicolor
# count    28.000000
# mean      2.796429
# std       0.280848
# min       2.300000
# 25%       2.600000
# 50%       2.800000
# 75%       3.000000
# max       3.400000
# Name: sepal_width, dtype: float64
# ...

# %%
# For virginica & versicolor: Compare the mean petal_width using the Mann-Whitney test (scipy.stats.mannwhitneyu)
# to see if there is a significant difference between the two groups. Do the same for the other measurement types.
from scipy.stats import mannwhitneyu

# compare mean petal_width for virginica and versicolor using Mann-Whitney test
virginica_pw = train[train.species == 'virginica'].petal_width
versicolor_pw = train[train.species == 'versicolor'].petal_width
u, p_value = mannwhitneyu(virginica_pw, versicolor_pw)
print("Mann-Whitney test for mean petal_width between virginica and versicolor:")
print("U-statistic:", u)
print("p-value:", p_value)

# compare mean sepal_length for virginica and versicolor using Mann-Whitney test
virginica_sl = train[train.species == 'virginica'].sepal_length
versicolor_sl = train[train.species == 'versicolor'].sepal_length
u, p_value = mannwhitneyu(virginica_sl, versicolor_sl)
print("Mann-Whitney test for mean sepal_length between virginica and versicolor:")
print("U-statistic:", u)
print("p-value:", p_value)

# compare mean sepal_width for virginica and versicolor using Mann-Whitney test
virginica_sw = train[train.species == 'virginica'].sepal_width
versicolor_sw = train[train.species == 'versicolor'].sepal_width
u, p_value = mannwhitneyu(virginica_sw, versicolor_sw)
print("Mann-Whitney test for mean sepal_width between virginica and versicolor:")
print("U-statistic:", u)
print("p-value:", p_value)

# compare mean petal_length for virginica and versicolor using Mann-Whitney test
virginica_pl = train[train.species == 'virginica'].petal_length
versicolor_pl = train[train.species == 'versicolor'].petal_length
u, p_value = mannwhitneyu(virginica_pl, versicolor_pl)
print("Mann-Whitney test for mean petal_length between virginica and versicolor:")
print("U-statistic:", u)
print("p-value:", p_value)
# Out:
# Mann-Whitney test for mean petal_width between virginica and versicolor:
# U-statistic: 767.0
# p-value: 6.47119166980993e-10
# Mann-Whitney test for mean sepal_length between virginica and versicolor:
# U-statistic: 676.5
# p-value: 3.082029196534108e-06
# Mann-Whitney test for mean sepal_width between virginica and versicolor:
# U-statistic: 510.0
# p-value: 0.05257259139845694
# Mann-Whitney test for mean petal_length between virginica and versicolor:
# U-statistic: 776.5
# p-value: 2.9479835715150625e-10

# %% [markdown]
# # Document takeaways & any actions.
# Some takeaways from this analysis could be:
# - Petal width is a more useful measurement in distinguishing between the virginica and versicolor species.
# - We can use this information to build a model to predict the species of an iris flower based on its petal width measurement.
# - It is important to perform statistical tests to determine whether there are significant differences between mean values when comparing different groups.
#
# As for actions, we could explore other statistical tests to compare the mean values of each measurement type for the different iris species, and see if there are other significant differences that could be useful in predicting the species of an iris flower. We could also use machine learning algorithms to build a classification model and evaluate its accuracy in predicting the species of an iris flower.

# %%
sns.pairplot(train, hue='species')

# %%
sns.relplot(x='sepal_length', y='petal_width', hue='species', data=train)

# %%
melted_df = pd.melt(train.drop(columns=['species']), var_name='variable', value_name='measure')
sns.swarmplot(x='variable', y='measure', data=melted_df)
# Out:
# <AxesSubplot:xlabel='variable', ylabel='measure'>

# %%
# To answer the question of whether the sepal area is significantly different between the 'virginica' and
# 'setosa' species, we can perform a t-test and plot the sepal area for both species. 

train['sepal_area'] = train['sepal_length'] * train['sepal_width']

sns.boxplot(x='species', y='sepal_area', data=train)
 
# we are comparing the sepal area of two groups, we can use the independent samples t-test. Before performing the t-test, 
# we need to check if the assumptions of independence, normality, and equal variance are met.

# Assumptions:
# 1. Independence: Since the sepal area of one observation is not dependent on the sepal area of another observation, 
# the independence assumption is met.
# 2. Normality: We can check the normality assumption by creating histograms of sepal area for each species and
#  visually inspecting if they are approximately normally distributed.

sns.histplot(x='sepal_area', data=train[train['species']=='setosa'], kde=True)
sns.histplot(x='sepal_area', data=train[train['species']=='virginica'], kde=True)

from scipy.stats import levene

levene(train[train['species']=='setosa']['sepal_area'], train[train['species']=='virginica']['sepal_area'])

from scipy.stats import ttest_ind

ttest_ind(train[train['species']=='setosa']['sepal_area'], train[train['species']=='virginica']['sepal_area'])
# Out:
# Ttest_indResult(statistic=-2.226624411702259, pvalue=0.030164291645584197)

# %% [markdown]
# # Document takeaways and any actions.
# From this analysis, we have learned that the sepal area is significantly different between the 'setosa' and 'virginica' species. The 'virginica' species has a higher median sepal area compared to 'setosa'.
#
# To confirm this finding, we performed a t-test and checked the assumptions of independence, normality, and equal variance. All assumptions were met, and the t-test resulted in a p-value less than 0.05, indicating that we can reject the null hypothesis of equal means.
#
# As an action, we can further investigate the relationship between sepal area and species by performing additional analyses, such as a regression analysis, to quantify the relationship between the two variables. We can also look for other variables that may be significantly different between the two species and explore their relationships with other variables in the dataset.

# %% [markdown]
# # Part II BONUS PER MISTY

# %% [markdown]
# # PART 3
# Explore your telco data to discover drivers of churn
# Determine if certain columns should be dropped
# Determine if it would be valuable to bin some numeric columns
# Determine if it would be valuable to combine multiple columns into one.

# %%
train, validate, test = split_data(df_telco, target='churn')
train.shape, validate.shape, test.shape
# Out:
# ((3943, 31), (1691, 31), (1409, 31))

# %%
# Determine if certain columns should be dropped (payment_type_id', 'internet_service_type_id', 'contract_type_id', 'customer_id' , should
# be dropped but only customer_id if you do not need the specific customer informatio in the future)
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize the relationship between 'churn' and 'tenure'
sns.boxplot(x='churn', y='tenure', data=train)
plt.show()

# %%
# Determine if it would be valuable to bin some numeric columns (total charges needs to be numerical)

# Visualize the distribution of 'tenure'
sns.histplot(data=train, x="tenure", bins=20)
plt.show()

# Visualize the distribution of 'monthly_charges'
sns.histplot(data=train, x="monthly_charges", bins=20)
plt.show()

# Visualize the distribution of 'total_charges'
sns.histplot(data=train, x="total_charges", bins=20)
plt.show()

# %%
#  determine if it would be valuable to combine multiple columns into one: 
# It would not be valuable to combine columns

# %% [markdown]
# What are your drivers of churn?
# How much customers are getting charged... if they are paying alot they will churn.
#
# Does it make sense to combine any features?
# It doesn't
#
# Do you find any surprises?
# How many customers leave the first month.
#
# Document any and all findings and takeaways in your notebook using markdown.
